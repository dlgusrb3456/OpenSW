# %%
# import pandas as pd
# df = pd.DataFrame(np.random.rand(3,2), index=['m1','m2','m3'], columns = ['price','num'])
# df

# df['sum'] = np.sum(df,axis=1)
# df

# df['rate'] = df['price']/df['num']
# df

# print(df,"\n")
# print(df['num'],"\n")
# print(df['num']>0.5,"\n")
# df2 = df[df['num']>0.5]
# print(df2)

# import numpy as np
# print(np.sqrt(2))
# print(np.pi)
# print(np.sin(np.pi/2))
# print(np.cos(0))

# print(np.random.rand(5))
# print(np.random.choice(10,5))

# a = np.arange(10).reshape(2,5)
# print(a)

# print(a.shape)
# print(a.ndim)
# print(a.size)

# print(a[1,2])
# print(a[(0,3)])



# import matplotlib.pyplot as plt
# data1 = [1,2,3,4]
# data2 = [4,3,1,1]
# plt.title('plot graph')
# plt.plot(data1,'r.',label='circle')
# plt.plot(data2,'g^',label='triangle')
# plt.legend()
# plt.show()



# import matplotlib.pyplot as plt
# data = [10,20,30]
# plt.pie(data)
# plt.show()

# xdata = [1,2,3,4]
# ydata = [10,20,40,30]
# plt.scatter(xdata,ydata)
# plt.show()




# import matplotlib.pyplot as plt #boxplot
# import csv

# f=open('seoul.csv')
# data = csv.reader(f)
# next(data)

# month = [[],[],[],[],[],[],[],[],[],[],[],[]]

# for row in data:
#     if row[-1] != '':
#         month[int(row[0].split('-')[1])-1].append(float(row[-1]))

# plt.boxplot(month)
# plt.show()





# import csv
# f= open('seoul.csv')
# data = csv.reader(f)
# next(data)
# result=[]
# for row in data:
#     if row[-1] != '':
#         if row[0].split('-')[1] == '02' and row[0].split('-')[2]=='14':
#             result.append(float(row[-1]))
# print(result)




# import matplotlib.pyplot as plt
# plt.hist([1,1,2,3,4,5,6,7,8,10])
# plt.show()



# import matplotlib.pyplot as plt

# xdata=[1,2,3,4]
# ydata = [10,5,20,50]
# plt.plot(xdata,ydata)
# plt.show()

# xdata = [1,2,3,4]
# ydata = [10,25,37,50]
# plt.bar(xdata,ydata)
# plt.show()

# plt.barh(xdata,ydata)
# plt.show()


# import csv
# class Point:
#     def __init__(self,x=0,y=0):
#         self.x=x
#         self.y =y
#     def move(self,x,y):
#         self.x += x
#         self.y += y
#     def show(self):
#         print("({0:d},{1:d})".format(self.x,self.y))
        
# class Box(Point):

#     def __init__(self,p1,p2):
#         self.p1 = p1
#         self.p2 = p2
#     def move(self,dx,dy):
#         p1.move(dx,dy)
#         p2.move(dx,dy)
#         #self.p2 = super().move(dx,dy)
#     def show(self):
#         self.p1.show()
#         self.p2.show()

# p1 = Point(1,2)
# p1.show()
# p2=Point(3,4)
# p2.show()

# b=Box(p1,p2)
# b.move(1,1)
# b.show()



# f = open('move.csv','r',encoding = 'cp949')
# data = csv.reader(f,delimiter=',')
# for row in data:
#     print(row)
# f.close

# f = open('new.txt', 'w') #w로 열면 다 사라지니 이어 쓰려면 'a' 옵션 주기
# for i in range(1,11):
# data = “{0:d} line.\n“.format(i)
# f.write(data)
# f.close()


#f=open('test.txt','r',encoding = 'cp949')
# data = f.read()
# print(data) #둘 다 됨


# for line in f:
#     print(line)
#     print("adsf")

# line = f.readline() #한 라인
# print(line)

# lines = f.readlines() # 전체 읽어서 리스트
# print(lines)

f.close()
